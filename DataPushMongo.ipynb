# %%
from pymongo import MongoClient # import mongo client to connect
import json # import json to load credentials
import urllib.parse

# load credentials from json file
with open('credentials_mongodb.json') as f:
    login = json.load(f)

# assign credentials to variables
username = login['username']
password = urllib.parse.quote(login['password'])
host = login['host']
url = "mongodb+srv://{}:{}@{}/?retryWrites=true&w=majority".format(username, password, host)

# %%
# Step 1: Connect to your MongoDB cluster
client = MongoClient(url)
client.drop_database('steam')

# Step 2: Create a new database named 'steam' and store it in a variable named db
db = client.steam

# Step 3: Create a collection named 'games' and insert sample documents
games = db.games

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
json_file_path = 'games1.json'
import json
# Load JSON data from the file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# %%
#Insert Data to Mongo
games.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\matha\Downloads\Steam_Pyspark_fundamentals\.venv\Lib\site-packages\pymongo\synchronous\pool.py:590, in Connection.receive_message(self, request_id)
#     589 try:
# --> 590     return receive_message(self, request_id, self.max_message_size)
#     591 except BaseException as error:
#
# File c:\Users\matha\Downloads\Steam_Pyspark_fundamentals\.venv\Lib\site-packages\pymongo\synchronous\network.py:320, in receive_message(conn, request_id, max_message_size)
#     319 # Ignore the response's request id.
# --> 320 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     321 # No request_id for exhaust cursor "getMore".
#
# ...
